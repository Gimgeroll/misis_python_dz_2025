# %%
print ("Меня зовут Саид, и я готов страдать на курсе!")
# Out:
# Меня зовут Саид, и я готов страдать на курсе!

# %% [markdown]
# # Приветствую!
# ## Кратко обо мне:
# Меня зовут Саид, мне 21 год, увлекаюсь всякой фигнёй:
# * Бразильское джиу-Джитсу
# * Аниме
# * Видеоигры
# * Проводить время с невестой
# * Баловаться
#
# В целом больше нечего рассказать, но мне надо еще использовать пронумерованный список, поэтому просто расставлю мои увлечения в алфавитном порядке:
# 1. Баловаться
# 2. Проводить время с невестой
# 3. Бразильское джиу-джитсу
# 4. Аниме
# 5. Видеоигры
# Все короче, спасибо за внимание

# %%
print ('Остаток от деления 77 на 22 равен', 77%22)
# Out:
# Остаток от деления 77 на 22 равен 3

# %%
print ('Число 22 четное, так как при делении его на 2, получаем остаток', 22%2)
# Out:
# Число 22 четное, так как при делении его на 2, получаем остаток 0

# %%
print ('86 в степени 7 равняется', 86**7)
# Out:
# 86 в степени 7 равняется 34792782221696

# %%
print ('Квадратный корень из 3686400 равняется', 3686400**0.5)
# Out:
# Квадратный корень из 3686400 равняется 1920.0
